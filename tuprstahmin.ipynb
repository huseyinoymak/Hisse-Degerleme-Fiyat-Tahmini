# %%
import pandas as pd
import yfinance as yf
import numpy as np
from isyatirimhisse import fetch_data, fetch_financials, visualize_data

# %%
tuprs=yf.download("TUPRS.IS",start="2018-01-01",end="2023-10-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
symbol='TUPRS'
start_year='2016'
end_year='2023'
save_to_excel=True
language='tr'

veri = fetch_financials(
    symbol=symbol,
    start_year=start_year,
    end_year=end_year,
    save_to_excel=save_to_excel,
    language=language
)
bilanco=pd.read_excel("finansallar_TUPRS_20231001.xlsx")
bilanco=bilanco.T

# %%
bilanco.columns=bilanco.iloc[1]
bilanco=bilanco.drop([bilanco.index[0],bilanco.index[1]])
bilanco["Çeyreklik Kar"]=0

# %%
for i in range(1,30):
   if i%4==0:
      bilanco["Çeyreklik Kar"].iloc[i]=bilanco["DÖNEM KARI (ZARARI)"].iloc[i]
   else:
      bilanco["Çeyreklik Kar"].iloc[i]=bilanco["DÖNEM KARI (ZARARI)"].iloc[i]-bilanco["DÖNEM KARI (ZARARI)"].iloc[i-1]
bilanco["Çeyreklik Kar"]
# Out:
# 2016/3               0
# 2016/6       335011000
# 2016/9       585738000
# 2016/12      808927000
# 2017/3       875759000
# 2017/6      1463521000
# 2017/9       999818000
# 2017/12      501458000
# 2018/3       386787000
# 2018/6      1035290000
# 2018/9       550687000
# 2018/12     1788681000
# 2019/3      -362295000
# 2019/6       885904000
# 2019/9      -140172000
# 2019/12      201893000
# 2020/3     -2249085000
# 2020/6      -162291000
# 2020/9      -394966000
# 2020/12      383417000
# 2021/3      -652256000
# 2021/6      1722416000
# 2021/9      1066251000
# 2021/12     1476813000
# 2022/3      1145064000
# 2022/6     10853901000
# 2022/9     11618668000
# 2022/12    17642934000
# 2023/3      6792657000
# 2023/6      7331480000
# Name: Çeyreklik Kar, dtype: int64

# %%
bilanco["Yıllıklandırılmış Kar"]=bilanco["Çeyreklik Kar"].rolling(4).sum()
bilanco=bilanco.dropna()
bilanco["Yıllıklandırılmış Kar"]
# Out:
# 2018/3     3.351584e+09
# 2018/6     2.923353e+09
# 2018/9     2.474222e+09
# 2018/12    3.761445e+09
# 2019/3     3.012363e+09
# 2019/6     2.862977e+09
# 2019/9     2.172118e+09
# 2019/12    5.853300e+08
# 2020/3    -1.301460e+09
# 2020/6    -2.349655e+09
# 2020/9    -2.604449e+09
# 2020/12   -2.422925e+09
# 2021/3    -8.260960e+08
# 2021/6     1.058611e+09
# 2021/9     2.519828e+09
# 2021/12    3.613224e+09
# 2022/3     5.410544e+09
# 2022/6     1.454203e+10
# 2022/9     2.509445e+10
# 2022/12    4.126057e+10
# 2023/3     4.690816e+10
# 2023/6     4.338574e+10
# Name: Yıllıklandırılmış Kar, dtype: float64

# %%
bilanco["Yıllıklandırılmış Kar"].plot(kind="line",figsize=(12,5),title="Yıllık Kar")
# Out:
# <Axes: title={'center': 'Yıllık Kar'}>

# %%
fiyat=pd.DataFrame()
dönem=pd.date_range(start="2018-03-30",end="2023-10-01",freq="Q")
fiyat["Fiyat"]=tuprs["Close"].resample("Q").last()



# Güncellenmiş DataFrame'i gösterelim
fiyat
# Out:
# 2021-12-31                                   1477304000    1476813000
# 2022-03-31                                   3302824000    1145064000
# 2022-06-30                                  15958296000   10853901000
# 2022-09-30                                  30001429000   11618668000
# 2022-12-31                                  45971985000   17642934000
# 2023-03-31                                  11437621000    6792657000
# 2023-06-30                                  20131398000    7331480000
#
# TUPRS      Yıllıklandırılmış Kar
# 2018-03-31          3.351584e+09
# 2018-06-30          2.923353e+09
# 2018-09-30          2.474222e+09
# 2018-12-31          3.761445e+09
# 2019-03-31          3.012363e+09
# 2019-06-30          2.862977e+09
# 2019-09-30          2.172118e+09
# 2019-12-31          5.853300e+08
# 2020-03-31         -1.301460e+09
# 2020-06-30         -2.349655e+09
# 2020-09-30         -2.604449e+09
# 2020-12-31         -2.422925e+09
# 2021-03-31         -8.260960e+08
# 2021-06-30          1.058611e+09
# 2021-09-30          2.519828e+09
# 2021-12-31          3.613224e+09
# 2022-03-31          5.410544e+09
# 2022-06-30          1.454203e+10
# 2022-09-30          2.509445e+10
# 2022-12-31          4.126057e+10
# 2023-03-31          4.690816e+10
# 2023-06-30          4.338574e+10
#
# [22 rows x 149 columns]

# %%
df1=pd.DataFrame(fiyat.head(22))
df1["Ödenmiş Sermaye"]=bilanco["Ödenmiş Sermaye"].astype(float)
df1["Özkaynak"]=bilanco["Özkaynaklar"].astype(float)
df1["Duran Varlıklar"]=bilanco["Duran Varlıklar"].astype(float)
df1["Dönen Varlıklar"]=bilanco["Dönen Varlıklar"].astype(float)
df1["Kısa Vadeli Yükümlülükler"]=bilanco["Kısa Vadeli Yükümlülükler"].astype(float)
df1["Uzun Vadeli Yükümlülükler"]=bilanco["Uzun Vadeli Yükümlülükler"].astype(float)
df1["Toplam Yükümlülük"]=df1["Kısa Vadeli Yükümlülükler"]+df1["Uzun Vadeli Yükümlülükler"]
df1["Çeyreklik Kar"]=bilanco["Çeyreklik Kar"].astype(float)
df1["Yıllıklandırılmış Kar"]=bilanco["Yıllıklandırılmış Kar"].astype(float)
df1["HBK"]=df1["Yıllıklandırılmış Kar"]/df1["Ödenmiş Sermaye"]
df1["Toplam Varlıklar"]=df1["Duran Varlıklar"]+df1["Dönen Varlıklar"]
df1
# Out:
#                 Fiyat  Ödenmiş Sermaye      Özkaynak  Duran Varlıklar  \
# Date
# 2018-03-31  15.542857     2.504190e+08  7.341450e+09     1.787333e+10
# 2018-06-30  15.485714     2.504190e+08  8.052826e+09     1.825045e+10
# 2018-09-30  19.085714     2.504190e+08  7.517618e+09     1.881608e+10
# 2018-12-31  16.642857     2.504190e+08  9.945829e+09     1.907352e+10
# 2019-03-31  17.814285     2.504190e+08  1.181468e+10     2.554416e+10
# 2019-06-30  16.400000     2.504190e+08  1.302556e+10     2.655035e+10
# 2019-09-30  20.514284     2.504190e+08  1.299984e+10     2.673530e+10
# 2019-12-31  18.085714     2.504190e+08  1.313654e+10     2.759260e+10
# 2020-03-31  10.835714     2.504190e+08  1.079117e+10     2.801768e+10
# 2020-06-30  12.857142     2.504190e+08  1.032834e+10     2.816125e+10
# 2020-09-30  11.385714     2.504190e+08  9.870505e+09     2.856028e+10
# 2021-12-31               2.234741e+10       8.717611e+10   1.476813e+09
# 2022-03-31               1.996030e+10       1.006868e+11   1.145064e+09
# 2022-06-30               1.984162e+10       1.318849e+11   1.085390e+10
# 2022-09-30               2.388789e+10       1.185868e+11   1.161867e+10
# 2022-12-31               2.281115e+10       1.017066e+11   1.764293e+10
# 2023-03-31               2.137752e+10       8.960258e+10   6.792657e+09
# 2023-06-30               2.810840e+10       1.135959e+11   7.331480e+09
#
#             Yıllıklandırılmış Kar         HBK  Toplam Varlıklar
# Date
# 2018-03-31           3.351584e+09   13.383905      3.818450e+10
# 2018-06-30           2.923353e+09   11.673847      4.020197e+10
# 2018-09-30           2.474222e+09    9.880329      4.906618e+10
# 2018-12-31           3.761445e+09   15.020605      4.003573e+10
# 2019-03-31           3.012363e+09   12.029291      5.360604e+10
# 2019-06-30           2.862977e+09   11.432747      5.628106e+10
# 2019-09-30           2.172118e+09    8.673934      5.568072e+10
# 2019-12-31           5.853300e+08    2.337403      5.551156e+10
# 2020-03-31          -1.301460e+09   -5.197130      5.095619e+10
# 2020-06-30          -2.349655e+09   -9.382894      5.555120e+10
# 2020-09-30          -2.604449e+09  -10.400365      5.361414e+10
# 2020-12-31          -2.422925e+09   -8.802410      6.361423e+10
# 2021-03-31          -8.260960e+08   -3.298855      6.978712e+10
# 2021-06-30           1.058611e+09    4.227359      7.503928e+10
# 2021-09-30           2.519828e+09   10.062447      8.106894e+10
# 2021-12-31           3.613224e+09   13.126729      1.062571e+11
# 2022-03-31           5.410544e+09   21.605964      1.166518e+11
# 2022-06-30           1.454203e+10   58.070789      1.600352e+11
# 2022-09-30           2.509445e+10   91.167331      1.644872e+11
# 2022-12-31           4.126057e+10  149.898339      1.688923e+11
# 2023-03-31           4.690816e+10  170.415866      1.510958e+11
# 2023-06-30           4.338574e+10   22.517038      1.819522e+11

# %%
X=df1[["Ödenmiş Sermaye","Özkaynak","Toplam Varlıklar","Toplam Yükümlülük","Çeyreklik Kar","HBK","Dönen Varlıklar","Duran Varlıklar","Kısa Vadeli Yükümlülükler","Uzun Vadeli Yükümlülükler","Yıllıklandırılmış Kar"]]
y=df1["Fiyat"]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Veri ölçekleme
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)

# PCA uygulama
pca = PCA(n_components=3)  # 10 ana bileşen seç, bu sayıyı değiştirebilirsin
principal_components = pca.fit_transform(scaled_data)

# Varyansı kontrol et
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.76402008, 0.10936523, 0.073839  ])

# %%
X=principal_components
y=df1["Fiyat"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
import pandas as pd
import statsmodels.api as sm



# Modeli eğitin



results = model.fit(X_train, y_train)

# Modelin özetini görüntüleyin
results.score(X_train,y_train)
# Out:
# 0.9677968386893779

# %%
tahmin1=pd.DataFrame(results.predict(X_test),columns=["Tahmin"],index=y_test.index)
tahmin1["Gerçek"]=y_test
tahmin1=tahmin1.sort_index()
tahmin1
# Out:
#                Tahmin     Gerçek
# Date
# 2018-03-31  17.403332  15.542857
# 2018-06-30  17.607139  15.485714
# 2018-12-31  19.295152  16.642857
# 2019-06-30  19.517742  16.400000
# 2020-03-31  14.473873  10.835714
# 2020-12-31  16.045798  15.528571
# 2021-06-30  18.318188  13.535714
# 2021-12-31  22.367809  22.057142
# 2023-03-31  69.803862  75.728569

# %%
import matplotlib.pyplot as plt
plt.plot(tahmin1["Tahmin"],label="Tahmin")
plt.plot(tahmin1["Gerçek"],label="Gerçek")
plt.legend()

# %%
X=df1[["Ödenmiş Sermaye","Özkaynak","Toplam Yükümlülük","Çeyreklik Kar","HBK","Dönen Varlıklar","Duran Varlıklar","Kısa Vadeli Yükümlülükler","Uzun Vadeli Yükümlülükler","Yıllıklandırılmış Kar"]]
y=df1["Fiyat"]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd
import numpy as np


# Tahminleri saklamak için bir liste
predictions = []

# Her bir sütun için döngü
for i in range(0,10):  
    # SARIMAX modelini oluşturma
    sarimax_model = SARIMAX(X.iloc[:, i], 
                            order=(0, 1, 1), 
                            seasonal_order=(0, 1, 1, 4))  # Çeyreklik veri için mevsimsel periyot 4

    # Modeli eğitme
    sarimax_fit = sarimax_model.fit(disp=False)

    # Modelin özeti (isteğe bağlı)
    print(sarimax_fit.summary())

    # Gelecekteki 6 değeri tahmin etme
    future_predictions = sarimax_fit.get_forecast(steps=6).predicted_mean

    # Tahminleri listeye ekleme
    predictions.append(future_predictions)

# Tahminleri bir DataFrame'e dönüştürme
predictions_df = pd.DataFrame(predictions).T  # Transpoze alarak sütunlarla satırları ters çeviriyoruz
predictions_df.columns = X.columns  # Sütun adlarını X DataFrame'inden alıyoruz


extended_X = pd.concat([X, predictions_df], ignore_index=True)
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                   Ödenmiş Sermaye   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -360.838
# Date:                           Sun, 01 Oct 2023   AIC                            727.677
# Time:                                   18:15:51   BIC                            730.176
# Sample:                               03-31-2018   HQIC                           727.925
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.6904      1.251      0.552      0.581      -1.761       3.142
# ma.S.L4        0.0573      7.310      0.008      0.994     -14.270      14.385
# sigma2      1.294e+17        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               129.67
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):              60.19   Skew:                             3.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.46e+46. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                          Özkaynak   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -404.407
# Date:                           Sun, 01 Oct 2023   AIC                            814.813
# Time:                                   18:15:51   BIC                            817.313
# Sample:                               03-31-2018   HQIC                           815.062
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.5913      0.211      2.801      0.005       0.178       1.005
# ma.S.L4        0.3355      0.548      0.612      0.541      -0.739       1.410
# sigma2      3.107e+19        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.65   Jarque-Bera (JB):                 0.71
# Prob(Q):                              0.42   Prob(JB):                         0.70
# Heteroskedasticity (H):              11.22   Skew:                             0.45
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.73e+55. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                 Toplam Yükümlülük   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -421.099
# Date:                           Sun, 01 Oct 2023   AIC                            848.199
# Time:                                   18:15:51   BIC                            850.698
# Sample:                               03-31-2018   HQIC                           848.447
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1253      0.283      0.442      0.658      -0.430       0.681
# ma.S.L4       -0.5145      0.382     -1.346      0.178      -1.263       0.234
# sigma2       2.23e+20   3.54e-22   6.29e+41      0.000    2.23e+20    2.23e+20
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 0.23
# Prob(Q):                              0.86   Prob(JB):                         0.89
# Heteroskedasticity (H):               4.65   Skew:                            -0.12
# Prob(H) (two-sided):                  0.08   Kurtosis:                         2.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.63e+58. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                     Çeyreklik Kar   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -399.280
# Date:                           Sun, 01 Oct 2023   AIC                            804.561
# Time:                                   18:15:51   BIC                            807.060
# Sample:                               03-31-2018   HQIC                           804.809
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.0647      0.319      0.203      0.839      -0.561       0.690
# ma.S.L4       -0.5629      0.569     -0.989      0.323      -1.679       0.553
# sigma2      2.115e+19        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 6.57
# Prob(Q):                              0.96   Prob(JB):                         0.04
# Heteroskedasticity (H):              35.96   Skew:                            -0.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.4e+54. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                               HBK   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                 -87.538
# Date:                           Sun, 01 Oct 2023   AIC                            181.076
# Time:                                   18:15:51   BIC                            183.576
# Sample:                               03-31-2018   HQIC                           181.325
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.9993    162.791      0.006      0.995    -318.065     320.063
# ma.S.L4       -0.4315      1.907     -0.226      0.821      -4.169       3.306
# sigma2      1340.0633   2.19e+05      0.006      0.995   -4.27e+05     4.3e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.49   Jarque-Bera (JB):                62.92
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):             198.60   Skew:                            -2.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                   Dönen Varlıklar   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -420.719
# Date:                           Sun, 01 Oct 2023   AIC                            847.438
# Time:                                   18:15:51   BIC                            849.937
# Sample:                               03-31-2018   HQIC                           847.686
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1446      0.482      0.300      0.764      -0.800       1.090
# ma.S.L4       -0.4023      0.621     -0.648      0.517      -1.619       0.815
# sigma2      2.197e+20        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 2.12
# Prob(Q):                              0.89   Prob(JB):                         0.35
# Heteroskedasticity (H):               6.33   Skew:                             0.47
# Prob(H) (two-sided):                  0.04   Kurtosis:                         4.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.46e+56. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                   Duran Varlıklar   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -386.061
# Date:                           Sun, 01 Oct 2023   AIC                            778.122
# Time:                                   18:15:51   BIC                            780.621
# Sample:                               03-31-2018   HQIC                           778.370
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0657      0.264     -0.249      0.804      -0.583       0.452
# ma.S.L4        0.3367      0.218      1.548      0.122      -0.090       0.763
# sigma2      4.156e+18        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.23   Jarque-Bera (JB):                 0.38
# Prob(Q):                              0.14   Prob(JB):                         0.83
# Heteroskedasticity (H):              11.00   Skew:                             0.11
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:         Kısa Vadeli Yükümlülükler   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -420.317
# Date:                           Sun, 01 Oct 2023   AIC                            846.633
# Time:                                   18:15:51   BIC                            849.133
# Sample:                               03-31-2018   HQIC                           846.882
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1754      0.259      0.678      0.498      -0.332       0.683
# ma.S.L4       -0.5652      0.507     -1.114      0.265      -1.559       0.429
# sigma2      2.145e+20        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 0.19
# Prob(Q):                              0.81   Prob(JB):                         0.91
# Heteroskedasticity (H):               5.45   Skew:                            -0.19
# Prob(H) (two-sided):                  0.06   Kurtosis:                         2.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  4e+58. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:         Uzun Vadeli Yükümlülükler   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -396.576
# Date:                           Sun, 01 Oct 2023   AIC                            799.152
# Time:                                   18:15:51   BIC                            801.652
# Sample:                               03-31-2018   HQIC                           799.401
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0908      0.469     -0.194      0.846      -1.010       0.828
# ma.S.L4       -0.5691      0.531     -1.071      0.284      -1.610       0.472
# sigma2      1.504e+19        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 1.75
# Prob(Q):                              0.87   Prob(JB):                         0.42
# Heteroskedasticity (H):               1.96   Skew:                             0.71
# Prob(H) (two-sided):                  0.43   Kurtosis:                         2.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.75e+54. Standard errors may be unstable.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:             Yıllıklandırılmış Kar   No. Observations:                   22
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 4)   Log Likelihood                -402.081
# Date:                           Sun, 01 Oct 2023   AIC                            810.163
# Time:                                   18:15:51   BIC                            812.662
# Sample:                               03-31-2018   HQIC                           810.411
#                                     - 06-30-2023
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.7283      0.359      2.030      0.042       0.025       1.432
# ma.S.L4       -0.5068      0.778     -0.651      0.515      -2.033       1.019
# sigma2      2.959e+19   4.09e-21   7.23e+39      0.000    2.96e+19    2.96e+19
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.33   Jarque-Bera (JB):                 5.63
# Prob(Q):                              0.57   Prob(JB):                         0.06
# Heteroskedasticity (H):              19.56   Skew:                             1.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.74e+57. Standard errors may be unstable.

# %%
extended_X=extended_X.set_index(pd.date_range(start="2018-03-31",end="2025-01-01",freq="Q"))
extended_X["Yıllıklandırılmış Kar"]=extended_X["Çeyreklik Kar"].rolling(4).sum()
extended_X["HBK"]=extended_X["Yıllıklandırılmış Kar"]/extended_X["Ödenmiş Sermaye"]
extended_X=extended_X.dropna()
extended_X
# Out:
#             Ödenmiş Sermaye      Özkaynak  Toplam Yükümlülük  Çeyreklik Kar  \
# 2018-12-31     2.504190e+08  9.945829e+09       3.008990e+10   1.788681e+09
# 2019-03-31     2.504190e+08  1.181468e+10       4.179136e+10  -3.622950e+08
# 2019-06-30     2.504190e+08  1.302556e+10       4.325550e+10   8.859040e+08
# 2019-09-30     2.504190e+08  1.299984e+10       4.268088e+10  -1.401720e+08
# 2019-12-31     2.504190e+08  1.313654e+10       4.237502e+10   2.018930e+08
# 2020-03-31     2.504190e+08  1.079117e+10       4.016502e+10  -2.249085e+09
# 2020-06-30     2.504190e+08  1.032834e+10       4.522286e+10  -1.622910e+08
# 2020-09-30     2.504190e+08  9.870505e+09       4.374363e+10  -3.949660e+08
# 2018-12-31               1.594954e+10               1.414036e+10
# 2019-03-31               2.514518e+10               1.664619e+10
# 2019-06-30               2.699196e+10               1.626355e+10
# 2019-09-30               2.735773e+10               1.532315e+10
# 2019-12-31               2.812027e+10               1.425475e+10
# 2020-03-31               2.470684e+10               1.545818e+10
# 2020-06-30               2.644354e+10               1.877932e+10
# 2020-09-30               2.188961e+10               2.185402e+10
# 2020-12-31               2.876643e+10               2.192236e+10
# 2021-03-31               3.886958e+10               2.018986e+10
# 2021-06-30               4.379602e+10               1.872299e+10
# 2021-09-30               4.922227e+10               1.804636e+10
# 2021-12-31               6.482870e+10               2.234741e+10
# 2022-03-31               8.072647e+10               1.996030e+10
# 2022-06-30               1.120432e+11               1.984162e+10
# 2022-09-30               9.469894e+10               2.388789e+10
# 2022-12-31               7.889541e+10               2.281115e+10
# 2023-03-31               6.822506e+10               2.137752e+10
# 2023-06-30               8.548752e+10               2.810840e+10
# 2023-09-30               7.989469e+10               2.961965e+10
# 2023-12-31               7.727185e+10               3.012962e+10
# 2024-03-31               7.873765e+10               2.919652e+10
# 2024-06-30               9.486824e+10               3.216545e+10
# 2024-09-30               8.876199e+10               3.401322e+10
# 2024-12-31               8.613915e+10               3.452318e+10
#
#             Yıllıklandırılmış Kar
# 2018-12-31           3.761445e+09
# 2019-03-31           3.012363e+09
# 2019-06-30           2.862977e+09
# 2019-09-30           2.172118e+09
# 2019-12-31           5.853300e+08
# 2020-03-31          -1.301460e+09
# 2020-06-30          -2.349655e+09
# 2020-09-30          -2.604449e+09
# 2020-12-31          -2.422925e+09
# 2021-03-31          -8.260960e+08
# 2021-06-30           1.058611e+09
# 2021-09-30           2.519828e+09
# 2021-12-31           3.613224e+09
# 2022-03-31           5.410544e+09
# 2022-06-30           1.454203e+10
# 2022-09-30           2.509445e+10
# 2022-12-31           4.126057e+10
# 2023-03-31           4.690816e+10
# 2023-06-30           4.338574e+10
# 2023-09-30           3.886548e+10
# 2023-12-31           3.126745e+10
# 2024-03-31           2.926333e+10
# 2024-06-30           2.992327e+10
# 2024-09-30           3.073131e+10
# 2024-12-31           3.153935e+10

# %%
X=extended_X[["Ödenmiş Sermaye","Özkaynak","Toplam Yükümlülük","Çeyreklik Kar","HBK","Dönen Varlıklar","Duran Varlıklar","Kısa Vadeli Yükümlülükler","Uzun Vadeli Yükümlülükler","Yıllıklandırılmış Kar"]]

# %%
# Veri ölçekleme
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)

# PCA uygulama
pca = PCA(n_components=5)  
principal_components1 = pca.fit_transform(scaled_data)

# Varyansı kontrol et
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.7521414 , 0.16530152, 0.04773518, 0.01610426, 0.00876795])

# %%
y=df1["Fiyat"]
y.loc[pd.Timestamp('2023-09-30')] = 159
y=y.tail(20)
y
# Out:
# Date
# 2018-12-31     16.642857
# 2019-03-31     17.814285
# 2019-06-30     16.400000
# 2019-09-30     20.514284
# 2019-12-31     18.085714
# 2020-03-31     10.835714
# 2020-06-30     12.857142
# 2020-09-30     11.385714
# 2020-12-31     15.528571
# 2021-03-31     12.857142
# 2021-06-30     13.535714
# 2021-09-30     16.371428
# 2021-12-31     22.057142
# 2022-03-31     30.628571
# 2022-06-30     37.785713
# 2022-09-30     41.371429
# 2022-12-31     75.699997
# 2023-03-31     75.728569
# 2023-06-30     79.300003
# 2023-09-30    159.000000
# Freq: Q-DEC, Name: Fiyat, dtype: float64

# %%
model=LinearRegression()
model.fit(principal_components1[:20],y)
model.score(principal_components1[:20],y)
# Out:
# 0.9814895563235547

# %%
tahmin3=pd.DataFrame(model.predict(principal_components1),index=pd.date_range(start="2018-12-31",end="2025-01-01",freq="Q"),columns=["Tahmin"])
tahmin3
# Out:
#                 Tahmin
# 2018-12-31    9.364467
# 2019-03-31   13.843729
# 2019-06-30   17.719812
# 2019-09-30   20.552071
# 2019-12-31   25.282494
# 2020-03-31   20.808549
# 2020-06-30   12.109826
# 2020-09-30    4.557943
# 2020-12-31   13.988244
# 2021-03-31   11.018657
# 2021-06-30   17.097033
# 2021-09-30   19.598292
# 2021-12-31   25.289551
# 2022-03-31   23.241865
# 2022-06-30   34.650404
# 2022-09-30   45.036495
# 2022-12-31   76.735853
# 2023-03-31   73.370556
# 2023-06-30   86.574471
# 2023-09-30  153.559677
# 2023-12-31  198.776676
# 2024-03-31  199.243431
# 2024-06-30  259.113956
# 2024-09-30  321.505091
# 2024-12-31  355.299354

# %%
y
# Out:
# Date
# 2018-12-31     16.642857
# 2019-03-31     17.814285
# 2019-06-30     16.400000
# 2019-09-30     20.514284
# 2019-12-31     18.085714
# 2020-03-31     10.835714
# 2020-06-30     12.857142
# 2020-09-30     11.385714
# 2020-12-31     15.528571
# 2021-03-31     12.857142
# 2021-06-30     13.535714
# 2021-09-30     16.371428
# 2021-12-31     22.057142
# 2022-03-31     30.628571
# 2022-06-30     37.785713
# 2022-09-30     41.371429
# 2022-12-31     75.699997
# 2023-03-31     75.728569
# 2023-06-30     79.300003
# 2023-09-30    159.000000
# Freq: Q-DEC, Name: Fiyat, dtype: float64

# %%
tahmin3.index = pd.to_datetime(tahmin3.index)
tahmin3.index = tahmin3.index.date
y.index = pd.to_datetime(y.index)
y.index = y.index.date

# %%
import matplotlib.dates as mdates
y.tail(12).plot(figsize=(12,7),label="Fiyat",color="black",linestyle="-",lw=3)
tahmin3["Tahmin"].tail(17).plot(label="Tahmin",color="red",linestyle="--",lw=3)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(bymonth=[1,4,7,10]))  # Çeyrekler için ay ayırıcıları
plt.xticks(rotation=45)
plt.scatter(tahmin3.index[-5::],tahmin3["Tahmin"][-5::],color="black",marker="o",s=70)
plt.title("TUPRS Fiyat Tahmini")
plt.xlabel("Tarih")
plt.ylabel("Fiyat")

for i in range(-5,-4):
    plt.annotate(str(round(tahmin3["Tahmin"][i],2)), (tahmin3.index[i], tahmin3["Tahmin"][i]), textcoords="offset points", xytext=(-5,5), ha='center',weight="bold",fontsize=10)
for i in range(-4,0):
    plt.annotate(str(round(tahmin3["Tahmin"][i],2)), (tahmin3.index[i], tahmin3["Tahmin"][i]), textcoords="offset points", xytext=(0,5), ha='center',fontsize=10,weight="bold")


plt.legend()
plt.show()
